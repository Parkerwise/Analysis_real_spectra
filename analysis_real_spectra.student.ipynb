# %% [markdown]
# <h2>OBSERVATIONAL ASTROPHYSICS – FALL 2024 Analysing real spectra (50 points)</h2>
#
# In this exercise we will look at the spectra of three objects that we took as part of the class in a previous year: M57 - a planetary nebula, Jupiter as seen in reflected sunlight, and the star Vega.
#
# All code elements that you need to change will be indicated with a #**************** section in the code
#
# There are 6 problems.
#
# **Due on Dec. 11 at 11:59am**

# %% [markdown]
# ### boiler plate

# %%
import astropy.units as u
from astropy.table import unique, Table
import numpy as np
from matplotlib import pyplot as plt
import os
from specutils import Spectrum1D
from numpy.random import uniform
import matplotlib.transforms as transforms

# %%
'''
This subroutine will allow us to draw lines on our spectra.  

It takes as input a dictionary of lines and plots a vertical line and a label at each wavelength of the dictionary.

'''
def lineplot(linelist):
    transDA = transforms.blended_transform_factory(
    ax.transData, ax.transAxes) #  from the transforms tutorial

    for line in linelist:
        if((line[1]>lammin) & (line[1]<lammax)):
            plt.axvline(linewidth=0.5,color='r',x=line[1])
            plt.text(line[1], #wavelength from list
                     uniform(0.5,1), # wiggle the labels so they don't overlap
                     line[0], # string label
                     transform=transDA,
                     color='red',
                     family='serif')

# %% [markdown]
# ## Problem 1 - identify lines (4 points)

# %% [markdown]
# ### Measure characteristics of the spectrum
#
# This spectrum was taken with the Breyo telescope.  It has been fully reduced and wavelength calibrated.  The flux is delivered in each pixel.
#
# ### Identify features in spectrum of M57
#
# In this exercise you will identify various components of the spectrum of M57.  In doing this you can zoom in and out of the plot using the `ax.set_xlim` and `ax.set_ylim()` commands.
#
# Uncomment all the spectral features in the "linelist" variable that correspond to clear features in the spectrum.    *Note: Not all features have line designations in my list*

# %%
#read in the three spectra we took
m57_path = 'M57_Object_CROP.fit'
vega_path ='Vega_Object_CROP.fit'
jup_path = 'Jupiter_Object_CROP.fit'

specm57 = Spectrum1D.read(m57_path)
specjup = Spectrum1D.read(jup_path)
specvega = Spectrum1D.read(vega_path)

#plot the M57 spectrum
plt.figure(figsize = (14,6))
ax = plt.gca()
plt.plot(specm57.wavelength,specm57.flux,label="M57")
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel(r"$\lambda$",fontsize=20)
plt.ylabel("Relative Flux",fontsize=20)
plt.title('M57')

#**************
#your code here
#you can change these to zoom in and out of certain parts of the spectra.  
#Make a copy of these and change your copy so as to remember what the 
#original values were
fluxmin = 0
fluxmax = 30
lammin = 3600
lammax = 7400
ax.set_ylim([fluxmin,fluxmax])
ax.set_xlim([lammin,lammax])

#***************************
#your code here
#Uncomment all of the lines that correspond to identifiable features in the spectra
linelist = [
    ('[AR IV]',4740),
    ('[OII]',3727),
    ('[O III]',4363),
    ('[O III]',4959),
    ('[O III]',5007),
    ('[O I]',6300),
    ('[OI]',6363),
    ('[N II]',6548),
    ('[N II]',6584),
    ('[S II]',6716),
    ('[S II]',6731),
    ('CIII',4647),
    ('MgI',5170),
    ('FeI', 5270),
    ('Hepsilon',3970),
    ('Hdelta',4103),
    ('H gamma',4341),
    ('H beta',4861),
    ('H alpa',6563),
    ('NaD', 5890),
    ('HeII',4541),
    ('He II',4686),
    ('HeI',4471),
    ('HE II',5411),
    ('[CL III]',5517),
    ('[CL III]',5537),
    ('[N II]',5755),
    ('He I',5875),
    ('HeI',7065),
    ('[Ar III]',7135),
    ('FeI',5335)
]
#draw lines on the spectrum 

# These lines were derived from the block comment.
accepted_lines =[('[AR IV]', 4740),
                 ('[OII]', 3727),
                 ('[O III]', 4363),
                 ('[O III]', 4959),
                 ('NaD', 5890),
                  ('[O III]', 5007),
                  ('[O I]', 6300),
                  ('[OI]',6363),
                  ('[N II]', 6548),
                  ('[N II]', 6584),
                  ('[S II]', 6731),
                  ('Hepsilon', 3970),
                  ('H gamma', 4341),
                  ('H beta', 4861),
                  ('H alpa', 6563),
                  ('HeII', 4541),
                  ('He II', 4686),
                  ('[Ar III]', 7135)]

# I rewrote accepted lines as a dictionary for 2a
accepted_lines_dict = {'[AR IV]': 4740,
                       '[OII]': 3727,
                       '[O III]': 4363,
                       '[O III]': 4959,
                       'NaD': 5890,
                       '[O III]': 5007,
                       '[O I]': 6300,
                       '[OI]':6363,
                       '[N II]': 6548,
                       '[N II]': 6584,
                       '[S II]': 6731,
                       'Hepsilon': 3970,
                       'H gamma': 4341,
                       'H beta': 4861,
                       'H alpa': 6563,
                       'HeII': 4541,
                       'He II': 4686,
                       '[Ar III]': 7135}

lineplot(accepted_lines)
'''
# accepted_lines was generated using the following code
# code is designed to:
    # 1. Plot each line from linelist with appropriate x & y limits and vertical line
    # 2. Ask user if the vertical line and spectra match
    # 3. If answer is "y", line is appended to "accepted_lines"

# init accepted_lines list
accepted_lines = []
# iterates through each line in linelist
for line in linelist:
# plot line
    # plots spectra and vertical line
    plt.figure(figsize = (14,6))
    ax = plt.gca()
    plt.plot(specm57.wavelength,specm57.flux,label="M57")
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.xlabel(r"$\lambda$",fontsize=20)
    plt.ylabel("Relative Flux",fontsize=20)
    plt.title(f'{line[0]}')
    plt.axvline(linewidth=0.5,color='r',x=line[1])
    # wavelength lim is +- 50
    lammin = line[1] - 50
    lammax = line[1] + 50
    # using argmin, and list slicing, find max and min flux in window for limits
    lambda_min_index = np.argmin(abs(specm57.wavelength.value - lammin))
    lambda_max_index = np.argmin(abs(specm57.wavelength.value - lammax))
    fluxmin = np.min(specm57.flux[lambda_min_index:lambda_max_index])
    fluxmax = np.max(specm57.flux[lambda_min_index:lambda_max_index])
    ax.set_xlim([lammin,lammax])
    ax.set_ylim([fluxmin,fluxmax])
    plt.show()
# ask
    # asks user if line is acceptable
    is_real_line = input('is this a real line?')
    if is_real_line == 'y':
        accepted_lines = np.append(accepted_lines, line)
'''
# Out:
# <>:111: SyntaxWarning: invalid escape sequence '\l'
# <>:111: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_2130/438586647.py:111: SyntaxWarning: invalid escape sequence '\l'
#   '''
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59527.076389 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59527.033576 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59526.939630 from DATE-OBS'. [astropy.wcs.wcs]
# '\n# accepted_lines was generated using the following code\n# code is designed to:\n    # 1. Plot each line from linelist with appropriate x & y limits and vertical line\n    # 2. Ask user if the vertical line and spectra match\n    # 3. If answer is "y", line is appended to "accepted_lines"\n\n# init accepted_lines list\naccepted_lines = []\n# iterates through each line in linelist\nfor line in linelist:\n# plot line\n    # plots spectra and vertical line\n    plt.figure(figsize = (14,6))\n    ax = plt.gca()\n    plt.plot(specm57.wavelength,specm57.flux,label="M57")\n    plt.xticks(fontsize=15)\n    plt.yticks(fontsize=15)\n    plt.xlabel(r"$\\lambda$",fontsize=20)\n    plt.ylabel("Relative Flux",fontsize=20)\n    plt.title(f\'{line[0]}\')\n    plt.axvline(linewidth=0.5,color=\'r\',x=line[1])\n    # wavelength lim is +- 50\n    lammin = line[1] - 50\n    lammax = line[1] + 50\n    # using argmin, and list slicing, find max and min flux in window for limits\n    lambda_min_index = np.argmin(abs(specm57.wavelength.value - lammin))\n    lambda_max_index = np.argmin(abs(specm57.wavelength.value - lammax))\n    fluxmin = np.min(specm57.flux[lambda_min_index:lambda_max_index])\n    fluxmax = np.max(specm57.flux[lambda_min_index:lambda_max_index])\n    ax.set_xlim([lammin,lammax])\n    ax.set_ylim([fluxmin,fluxmax])\n    plt.show()\n# ask\n    # asks user if line is acceptable\n    is_real_line = input(\'is this a real line?\')\n    if is_real_line == \'y\':\n        accepted_lines = np.append(accepted_lines, line)\n'

# %% [markdown]
# ## Problem 2 - measure the spectral resolution of the spectrograph

# %% [markdown]
# #### Problem 2a - compute the quantities using a by eye estimates (4 points)

# %% [markdown]
# Using the code block below, measure the wavelength resolution $\Delta \lambda$ and the spectral resolution $R$ for the M57 spectra.  Any derivation you do to solve the problem must be explained here.
#
# ANSWER: R = $\frac{\lambda}{\Delta \lambda}$, $\lambda$ should be the central wavelength, $\Delta \lambda$ is the FWHM of our line. The reason for this is because our intrinsic width is smaller than $\Delta \lambda$, and whatever is causing the largest width in a line is what we will see for the width of that line.
#
# Assume that the intrinsic width of the spectral lines is significantly smaller than $\Delta\lambda$.
#
# We will try two different estimates, one using measurements by eye and one by fitting a model to the line.
#
# There are parts a-d in this problem.

# %%
#first zoom in on one emission line and plot it.
#Choose one of the identified lines, which are real, and which is isolated enough to properly characterize.
#plot the M57 spectrum
plt.figure(figsize = (14,6))
ax = plt.gca()
plt.plot(specm57.wavelength,specm57.flux,label="M57")
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel(r"$\lambda$",fontsize=20)
plt.ylabel("Flux",fontsize=20)
plt.title('M57')

#you can change these parameters to zoom in and out of certain parts of the spectra.  
#Make a copy of these parameters and change your copy so as to remember what the 
#original values were
#**************
#Your code here.
'''
fluxmin = 0
fluxmax = 30
lammin = 3600
lammax = 7400
ax.set_ylim([fluxmin,fluxmax])
ax.set_xlim([lammin,lammax])
'''
# wavelength lim is +- 50, chose H beta
# this is why I converted to a dict, so that this
# step is clear as to which wavelength we're using
# optimally I'd rewrite lineplot to work with dicts
# and replace the accepted_lines, but that'd
# serve no purpose
chosen_wavelength = accepted_lines_dict['H beta']
lammin = chosen_wavelength - 50
lammax = chosen_wavelength + 50
# using argmin, and list slicing, find max and min flux in window for limits
lambda_min_index = np.argmin(abs(specm57.wavelength.value - lammin))
lambda_max_index = np.argmin(abs(specm57.wavelength.value - lammax))
print(lambda_min_index)
fluxmin = np.min(specm57.flux[lambda_min_index:lambda_max_index])
fluxmax = np.max(specm57.flux[lambda_min_index:lambda_max_index])
ax.set_ylim([fluxmin-2 ,fluxmax+2])  # +- 2 gives free space in plot
ax.set_xlim([lammin,lammax])

#In the following section of code you will need to estimate the continuum and the peak of the line as horizontal lines.  
# continuum is estimated by the mean from a line free area
# lower and upper range are just by eye estimates of line free area
lineless_lower_index = 2675
# converts lower index into lower wavelength (magnitude, no units)
lineless_lower_wavelength = specm57.wavelength[lineless_lower_index].value
# plots vertical lines to show region is, in fact, lineless
plt.axvline(lineless_lower_wavelength, color='green', label='lower bound')

# same methods as lower bound with different index
lineless_upper_index = 2750
lineless_upper_wavelength = specm57.wavelength[lineless_upper_index].value
plt.axvline(lineless_upper_wavelength, color='blue', label = 'upper bound')

# takes the mean from our lineless region to find mean continuum
continuum_level = np.mean(specm57.flux[lineless_lower_index:lineless_upper_index])
# plots continuum level onto graph
plt.axhline(continuum_level, color='red', label='line bounds')

# line peak is derived from the limits we used earlier
line_peak = fluxmax
# plots line peak
plt.axhline(line_peak, color='red')
# plots a legend to identify all the lines
plt.legend()

#Provide a calculation to determine the half maximum
# Naturally, half-max is, half the maximum
halfmax = fluxmax/2
plt.axhline(halfmax,color='magenta',linestyle='--')

#Now find wavelengths corresponding to short and long wavelength sides of FWHM by using the vertical 
#lines that will be drawn on the graph
# by using the methods of difference and argmin, I found the points in which the
# flux is equal to the half max. Since there are two points I had to use
# argpartition instead of argmin.
fwhm_flux_difference = abs(specm57.flux[lambda_min_index:lambda_max_index] - halfmax)
# full disclosure, theres no way I could've known which index would be the lower
# and higher index from argpartition. I just had to print lowlam and highlam to see
# which index is which.
lowlam_index = np.argpartition(fwhm_flux_difference, 1)[1]
lowlam = specm57.wavelength[lowlam_index+lambda_min_index].value
plt.axvline(lowlam,color='goldenrod')
highlam_index = np.argpartition(fwhm_flux_difference, 1)[0]
highlam = specm57.wavelength[highlam_index+lambda_min_index].value
plt.axvline(highlam,color='goldenrod')

# FWHM, hopefully this is obvious
fwhm_guess = highlam - lowlam
mean_guess = fwhm_guess/2 + lowlam
resolution_guess = mean_guess / fwhm_guess
print(f"R-by-eye: {resolution_guess:.2f}")
# Out:
# 2669
# R-by-eye: 417.19

# %%
from specutils.fitting.continuum import fit_generic_continuum
from specutils.spectra import Spectrum1D, SpectralRegion
import warnings
import astropy.units as u
from astropy.modeling import models, fitting

#you will need to define spectral regions to exclude.  The fitting algorithm fits a running median of the spectra, 
#which helps to get rid of weak emission lines, however, you should try to define windows to remove the other emission lines. 
#We make these regions using the "SpectralRegion" function and I give you two such regions below to demonstrate.  
#I exclude the very blue short wavelength region as it is hard to fit that with the function I use and because
#there are no emission lines of interest there.
#You should fill in the other regions.
#these are lists of the lower and upper bounds of the regions not to fit
lamlow = [3500,4300]
lamhigh = [4100,4750]

#************************
#your other regions go here.  
#a list of the lower bounds
lamlow.extend([4825, 6500, 5400, 5650, 7100, 6250, 6700])
#a list of the upper bounds
lamhigh.extend([5100, 6625, 5500, 6100, 7150, 6350, 6750])

#this creates the SpectralRegion that contains all of the excluded regions
for ilam,lam in enumerate(lamlow):
    #create the excl_region for the first region
    if ilam==0:
        excl_region = SpectralRegion(lamlow[ilam] * u.Angstrom,lamhigh[ilam] * u.Angstrom)

    #append to it for the following regions.
    excl_region += SpectralRegion(lamlow[ilam] * u.Angstrom,lamhigh[ilam] * u.Angstrom)
    
#*************
#You will need to play around with the degree of the Chebyshev polynomial and the median_window parameter to get a good fit.  
#Your continuum subtracted spectrum should
with warnings.catch_warnings():  # Ignore warnings
    warnings.simplefilter('ignore')
    fitted_continuum = fit_generic_continuum(specm57,exclude_regions=excl_region, median_window=1  ,
                                             model=models.Chebyshev1D(degree=5  ))
#this is the fitted continuum
y_fit = fitted_continuum(specm57.wavelength)

#plot the spectrum and the continuum fit
f,(ax1,ax2) = plt.subplots(2,1,figsize=(12,10))  
ax1.plot(specm57.wavelength, specm57.flux,label='data')  
ax1.plot(specm57.wavelength, y_fit,label='continuum fit')  
ax1.set_title("Continuum Fitting")  
ax1.set_ylim(-2,30)
ax1.set_xlabel("$\lambda$",fontsize=20)
ax1.set_ylabel("Flux",fontsize=20)

#to help you decide which regions to exclude, plot gray regions that are excluded.
for ilam,lam in enumerate(lamlow):
    ax1.fill_betweenx([-100,100],lamlow[ilam],x2=lamhigh[ilam],color='gray',alpha=0.2,label='exclued regions')

    #only make the legend after the first iteration so it only makes one box
    if ilam==0:
        ax1.legend(fontsize=12)

#plot the continuum subtracted spectrum
contsubspec = specm57.flux - y_fit
ax2.plot(specm57.wavelength, contsubspec, label='continuum subtracted data')  
ax2.set_title("Continuum subtracted spectrum")  
ax2.set_ylim(-2,10)
ax2.axhline(0.0,color='red',linestyle=':',linewidth=3,label='zero for reference')
ax2.set_xlabel("$\lambda$",fontsize=20)
ax2.set_ylabel("Flux",fontsize=20)
ax2.legend(fontsize=12)

#this optimizes the spacing between the figures
f.tight_layout()
# Out:
# <>:49: SyntaxWarning: invalid escape sequence '\l'
# <>:66: SyntaxWarning: invalid escape sequence '\l'
# <>:49: SyntaxWarning: invalid escape sequence '\l'
# <>:66: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_2130/25539565.py:49: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel("$\lambda$",fontsize=20)
# /tmp/ipykernel_2130/25539565.py:66: SyntaxWarning: invalid escape sequence '\l'
#   ax2.set_xlabel("$\lambda$",fontsize=20)

# %% [markdown]
# #### Problem 2b - compute the quantities by fitting a function (8 points)

# %% [markdown]
# First we need to fit a continuum and subtract it, as the fitting functions require a continuum subtracted spectrum.  The result of this should be a continuum with a level of zero.  Your continuum subtracted spectrum should have as flat of a continuum as possible, ignoring the regions that you exclude from the fitting (see below).

# %% [markdown]
# Now let's zoom in on the Hbeta line and see how well our continuum fit did.

# %%
from specutils.fitting import fit_lines

#first zoom in on the Hbeta line
f,ax = plt.subplots(figsize=(12,5))  
ax.plot(specm57.wavelength, contsubspec, label='continuum subtracted data')  
ax.set_title("Continuum subtracted spectrum")  
ax.set_xlim(4800,4900)
ax.set_ylim(-2,10)
ax.axhline(0.0,color='red',linestyle=':',linewidth=3,label='zero for reference')
ax.set_xlabel("$\lambda$",fontsize=20)
ax.set_ylabel("Flux",fontsize=20)
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\l'
# <>:10: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_2130/1816950597.py:10: SyntaxWarning: invalid escape sequence '\l'
#   ax.set_xlabel("$\lambda$",fontsize=20)
# Text(0, 0.5, 'Flux')

# %% [markdown]
# turns out that even our best efforts in Problem 2b couldn't get the continuum to be zero.  That's because our continnuum fit was trying to fit all the continuum everywhere, when in reality we only needed it in one part.  So let's fix this by computing the mean of the continuum away from the line and correcting the line.

# %%
#compute the average of a region away from the line using the zoom in above
#*********************
#your code here
#find the region with a boolean array
contlam = (specm57.wavelength>4800 *u.Angstrom) & (specm57.wavelength<4840 * u.Angstrom)

#now compute the average of the continuum subtracted spectrum in that region and print it out.
# takes the mean of the list indexed by contlam
meancont = np.mean(contsubspec[contlam])
print('mean continuum = %5.3f' % meancont)

#now correct the continuum subtracted spectrum by that amount
contsubspec -= meancont

#first zoom in on the Hbeta line
f,ax = plt.subplots(figsize=(12,5))  
ax.plot(specm57.wavelength, contsubspec, label='continuum subtracted data')  
ax.set_title("Continuum subtracted spectrum - second iteration")  
ax.set_xlim(4800,4900)
ax.set_ylim(-2,10)
ax.axhline(0.0,color='red',linestyle=':',linewidth=3,label='zero for reference')
ax.set_xlabel("$\lambda$",fontsize=20)
ax.set_ylabel("Flux",fontsize=20)
# Out:
# mean continuum = 0.000
# <>:22: SyntaxWarning: invalid escape sequence '\l'
# <>:22: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_2130/3502817808.py:22: SyntaxWarning: invalid escape sequence '\l'
#   ax.set_xlabel("$\lambda$",fontsize=20)
# Text(0, 0.5, 'Flux')

# %% [markdown]
# #### Problem 2c (3 points)

# %% [markdown]
# Comment on whether the spectra now has a better continuum subtraction and how you know this.
#
# **your answer here**\
# The underlying shape of an observed spectrum is non-zero continuum emission. This background level can be subtracted off. After subtraction the emission should lie at zero, with some noise. The mean of the noise should be colinear with 0 flux. In our first subtraction, 0 is ~ 1 unit of flux higher than the continuum (we over subtracted). In the second iteration the noise lines up with 0, it is a much better subtraction.

# %% [markdown]
# #### Problem 2d (3 points)

# %% [markdown]
# Now you will need to fit a gaussian to the spectrum.  We blow up around the line and the run a Gaussian line fitter to estimate the parameters of the Gaussian.  You will then use these to measure the $\Delta \lambda$ and the spectral resolution $R$

# %%
#first zoom in on the Hbeta line
f,ax = plt.subplots(figsize=(12,5))  
ax.plot(specm57.wavelength, contsubspec, label='continuum subtracted data')  
ax.set_title("Continuum subtracted spectrum")  
ax.set_xlim(4800,4900)
ax.set_ylim(-2,10)
ax.axhline(0.0,color='red',linestyle=':',linewidth=3,label='zero for reference')
ax.set_xlabel("$\lambda$",fontsize=20)
ax.set_ylabel("Flux",fontsize=20)

#now fit a gaussian to the spectrum
# Fit the spectrum and calculate the fitted flux values (``y_fit``)
spectrum = Spectrum1D(flux=contsubspec, spectral_axis=specm57.wavelength)

#**********************
#you need to supply the initial guesses for the amplitude, mean, and stddev
#we are assuming thast the flux is unitless because the spectrum isn't calibrated.
# stddev is 1/2.358 the FWHM from our initial guess. 
# Other guesses come from 2a as well.
stddev_guess = fwhm_guess/2.3548
g_init = models.Gaussian1D(amplitude=line_peak, mean=mean_guess, stddev=stddev_guess)

#fit the line using the initial guesses
g_fit = fit_lines(spectrum, g_init,get_fit_info=True)
#determine the model flux
y_fit = g_fit(specm57.wavelength)
#plot model flux
ax.plot(specm57.wavelength,y_fit,color='goldenrod',label='Gaussian fit')
ax.legend(fontsize=12)

#print all the paramters
print(g_fit)

#assign the standard deviation to a variable
params = g_fit.param_sets
amp = params[0][0]
mean = params[1][0]
stddev = params[2][0]

#*********************
#Your code here
#you will need to use the fitted parameters to determine the Delta lambda and the spectral resolution
# FWHM (delta lam) is 2.3548 the stddev
deltalam = stddev*2.3548
print('Delta Lambda = %5.2f' % deltalam)

#calculate the spectral resolution
# spectral resolution is lam/delta lam, so the mean over delta lam.
specres = mean / deltalam
print('R = %6.2f' % specres)
# Out:
# Model: Gaussian1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Parameters:
#         amplitude            mean             stddev
#                            Angstrom          Angstrom
#     ----------------- ----------------- -----------------
#     7.160591746387379 4860.775317385662 4.154861228798224
# Delta Lambda =  9.78
# 4.154861228798224 4.947803001305138
# R = 496.82
# <>:8: SyntaxWarning: invalid escape sequence '\l'
# <>:8: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_2130/364803565.py:8: SyntaxWarning: invalid escape sequence '\l'
#   ax.set_xlabel("$\lambda$",fontsize=20)

# %% [markdown]
# Comment in this cell on how the two methods agree and which one you think is more reliable.  You must be quantitative in this discussion.
#
# **answer here**\
# By eye mean: 4860.73\
# Fit mean: 4860.77\
# By eye FWHM: 4.947803001305138\
# Fit FWHM: 4.154861228798224\
# The means agree pretty well. This means that the FWHM is the limiting factor here. The fit FWHM is smaller than the by eye. I imagine this is because the fit amplitude is > than the bye eye magnitude, but it could also do with the fact that the fit isn't really perfect. If the fit was visually more consistent with the data I'd tend to agree with the fit as the better resolution, but here I might have to go with the by-eye resolution

# %% [markdown]
# ## Problem 3 (4 points)

# %% [markdown]
# Assume that the slit went right through the center of the planetary nebula.  Using what you know about the composition of planetary nebula (not necessarily from this class), describe here from where the broad emission lines and sharp rise in flux at the blue end of the planetary nebula come from.
#
# **answer here**\
# Planetary nebula are quite hot, so their continuum should peak at low wavelengths (~ 3000 angstroms), so the I imagine the shift at the blue end is due continuum from the central star. The broad emission lines I imagine arise from the same phenomenon, since higher temperature gas will produce a wider maxwell-boltzmann distribution, widening the emission lines.

# %% [markdown]
# ## Problem 4

# %% [markdown]
# In this problem you see a comparison of Jupiter's spectrum to that of a G2V star similar to the sun. You will need to answer the following questions
#
# **a. Measure the temperature of each spectrum from the shape of the spectrum. (4 points)**
#
# **b. Compare the two temperatures.(4 points)**
#
# **c. All the visible light we see from Jupiter is reflected sunlight.  Do your best given your knowledge of how light propogates through different media to describe a possible origin for the relative values of the temperatures.  You can also include a discussion of the relative colors of the spectra.(4 points)**
#
# For each part here I would like a significant amount of discussion.  You will put your answers below the code.
#
#
# *As an aside, note that the very wide absorption lines longward of 6000$\mathring A$ in Jupiter's spectrum are absorption bands from molecules in Jupiter's atmosphere.  These bands absorb light over a wide wavelength range.*

# %%
#this is a comparison star from a library similar to that we used in our 
#very first spectral exercise.
starpath = '95128.txt'  #G2V
star1 = Table.read(starpath,format='ascii', names=('lambda','flam'))

#plot Jupiter
plt.figure(figsize = (14,6))
ax = plt.gca()
plt.plot(specjup.wavelength,specjup.flux*20,label="Jupiter")

#smooth the comparison stellar spectrum so that the many spectral features
#don't make the comparison difficult.  We use a boxcar filter of size "kernel_size"
#**********
#You should make the intial plot with a smoothing kernel of 1 to see how the unsmoothed 
#very high resolution G2V spectrum looks like.  Then you should change the kernel size to 20 to see 
#how it is easier to use.
#If you'd like you can play more with the kernel size, but it is not required.
kernel_size = 20
kernel = np.ones(kernel_size) / kernel_size
star1convflam = np.convolve(star1['flam'], kernel, mode='same')
#plot the convolved spectrum
# I decreased lw to help see behind the spectra better.
plt.plot(star1['lambda'],star1convflam*20, label = 'A G2V star', lw='0.75')

#**************
#you can change these parameters to zoom in and out of certain parts of the spectra.  
#Make a copy of these parameters and change your copy so as to remember what the 
#original values were
fluxmax = 25
fluxmin = 0
ax.set_ylim([fluxmin,fluxmax])


plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
# Finds the max wavelength of each spectra using argmin.
# Ideally we would fit the spectra's continuum and find that max,
# but this will work in a pinch.
star1_max_lambda= star1['lambda'][np.argmax(star1['flam'])]
jup_max_lambda = specjup.wavelength[np.argmax(specjup.flux)].value
plt.vlines(star1_max_lambda, -50, 50, color='r', label=r'G2V max $\lambda$')
plt.vlines(jup_max_lambda, -50, 50, color='g', label=r'Jupiter max $\lambda$')
plt.legend(fontsize=20)
plt.xlabel("$\lambda$",fontsize=20)
plt.ylabel("Relative Flux",fontsize=20)
print(f"star1_max_lambda: {star1_max_lambda:.2f} A")
print(f"jup_max_lambda: {jup_max_lambda:.2f} A")
# Out:
# <>:44: SyntaxWarning: invalid escape sequence '\l'
# <>:44: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_2130/3625195366.py:44: SyntaxWarning: invalid escape sequence '\l'
#   plt.xlabel("$\lambda$",fontsize=20)
# star1_max_lambda: 4503.80 A
# jup_max_lambda: 5841.42 A

# %%
#***************
#Any code needed for problem 4b goes here.  Please print your temperatures.  
# I wasn't fully sure what constitutes 4a and 4b, so I found the max 
# wavelength for each spectra in the last code block.
# Here I calculate the temperature.

# in order to find temperature we use wiens law
# hopefully I don't have to put a derivation.
def wiens_law_temp(wavelength_angstroms): 
    # angstroms per meters (as it says!)
    ANGSTROMS_PER_METER = 1e-10
    # 0.0029 in m*K
    # multiply wavelength_angstroms by conversion
    temp_kelvin = 0.0029 / (wavelength_angstroms*ANGSTROMS_PER_METER)
    # returns temp
    return temp_kelvin


jup_temp = wiens_law_temp(jup_max_lambda)
star1_temp = wiens_law_temp(star1_max_lambda)
print(f"jup_temp: {jup_temp:.2f} K")
print(f"star1_temp: {star1_temp:.2f} K")

# again, not fully sure what "compare" means, but we can find T_jup/T_star
star1_jup_temp_ratio = star1_temp / jup_temp
print(f"star1_jup_temp_ratio: {star1_jup_temp_ratio:.3f}")
# Out:
# jup_temp: 4964.55 K
# star1_temp: 6439.01 K
# star1_jup_temp_ratio: 1.297

# %% [markdown]
# **answer to part a here**  Make sure to provide all calculations either in code or in LaTeX.\
# jup_temp: 4964.55 K\
# star1_temp: 6439.01 K

# %% [markdown]
# **answer to part b here**
# Make sure to provide all calculations either in code or in LaTeX.\
# star1_jup_temp_ratio: 1.297, star1 is around 4/3 times brighter than jupiter.

# %% [markdown]
# **answer to part c here**
# Make sure to provide all calculations either in code or in LaTeX.\
# If jupiter reflected all of the suns light equally, then we observe a spectra of jupiter that has a peak the same as the sun. That said, jupiter is pretty red, so it absorbs bluer light and reflects redder light. This shifts the peak to a colder temperature, thus we get a temperature that is ~700 K less than what we see in the sun.

# %% [markdown]
# ## Problem 5 - Identify features in spectrum of Jupiter (4 points)

# %% [markdown]
# In this exercise you will identify various components of the spectrum of Jupiter.  In doing this you can zoom in and out of the plot using the `ax.set_xlim` and `ax.set_ylim()` commands.
#
# Using what you know about the spectral lines in an A0V star and given the spectrum of Vega plotted below, identify as many of the lines as you can in the spectrum of Jupiter.  By "identify" I mean give the wavelength, the name of the element that makes the line, and which transition of that element causes the specific line.  If you think you should fine a line and can't write why it isn't there.  Please be detailed in your answer. *Note - The line at 6880$\mathring A$ is from the Earth's atmosphere and should be ignored*
# **answer here**\
# I can identify the balmer series of hydrogen in both spectra\
# H epsilon, 3970 A, n=7-2\
# \
# H delta, 4103 A, n=6-2\
# \
# H gamma, 4341 A, n=5-2\
# \
# H beta, 4861 A, n=4-2\
# \
# H alpa, 6563 A, n=3-2

# %%
#plot Vega and Jupiter, where I have scaled the flux of Jupiter so that they 
#better overlap. You can change that scaling
plt.figure(figsize = (14,6))
ax = plt.gca()
plt.plot(specvega.wavelength,specvega.flux,label="Vega")
plt.plot(specjup.wavelength,specjup.flux*5,label="Jupiter")

#**************
#you can change these parameters to zoom in and out of certain parts of the spectra.  
#Make a copy of these parameters and change your copy so as to remember what the 
#original values were
# line list, I deleted lines that weren't couccuring
linelist_vega = [
    # balmer series lines, defines A0V stars spectra
    ('H epsilon',3970),
    ('H delta',4103),
    ('H gamma',4341),
    ('H beta',4861),
    ('H alpa',6563),
]
lammin = 3000
lammax = 8000
'''
fluxmin = 
fluxmax = 
ax.set_ylim([fluxmin,fluxmax])
ax.set_xlim([lammin,lammax])
'''

lineplot(linelist_vega)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel("$\lambda [\AA]$",fontsize=20)
plt.ylabel("Relative Flux",fontsize=20)
plt.legend(fontsize=20)
# Out:
# <>:33: SyntaxWarning: invalid escape sequence '\l'
# <>:33: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_2130/358047567.py:33: SyntaxWarning: invalid escape sequence '\l'
#   plt.xlabel("$\lambda [\AA]$",fontsize=20)

# %% [markdown]
# ## Problem 6 - Discuss the physical conditions that drive line formation

# %% [markdown]
# In this exercise you will identify various components of the spectrum of Jupiter.  In doing this you can zoom in and out of the plot using the `ax.set_xlim` and `ax.set_ylim()` commands.

# %%
#plot Vega and M57, where I have scaled the flux of Jupiter so that they 
#better overlap. You can change that scaling
plt.figure(figsize = (12,6))
ax = plt.gca()
plt.plot(specm57.wavelength,specm57.flux,label="M57")
plt.plot(specvega.wavelength,specvega.flux*8,label="Vega")

#**************
#you can change these to zoom in and out of certain parts of the spectra.  
'''
fluxmin = 
fluxmax = 
lammin = 
lammax = 
ax.set_ylim([fluxmin,fluxmax])
ax.set_xlim([lammin,lammax])
'''
# accepted_lines, but I deleted all non-balmer lines
intersecting_lines = [('H epsilon', 3970),
                     ('H gamma', 4341),
                     ('H beta', 4861),
                     ('H alpa', 6563)]
print(intersecting_lines)
lineplot(intersecting_lines)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel("$\lambda [\AA]$",fontsize=20)
plt.ylabel("Relative Flux",fontsize=20)
plt.legend(fontsize=20)
# Out:
# [('H epsilon', 3970), ('H gamma', 4341), ('H beta', 4861), ('H alpa', 6563)]
# <>:27: SyntaxWarning: invalid escape sequence '\l'
# <>:27: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_2130/4221292100.py:27: SyntaxWarning: invalid escape sequence '\l'
#   plt.xlabel("$\lambda [\AA]$",fontsize=20)

# %% [markdown]
# There are lines in common between M57 and Vega but they are in absorption in Vega and in Emission in M57. Note that the lines do not perfectly line up in wavelength as the M57 spectrum has not been perfectly wavelength calibrated.
#
# **(6a) Identify the lines in common. (4 points)**
#
# answer here\
# H epsilon, 3970\
# \
# H gamma, 4341\
# \
# H beta, 4861\
# \
# H alpa, 6563\
#
# These are lines that are in both lists (linelist_vega), and (accepted_lines)
#
#
#
# **(6b) Explain why they are in emission in one spectrum and in absorption in the other.  Use your knowledge of Kirkhoffs laws. (4 points)**
#
# *Note - The line at 6880$\mathring A$ is from the Earth's atmosphere and should be ignored.*
#
# answer here\
# This has to do with kirckoff's laws. In
